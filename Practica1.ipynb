# %% [markdown]
# # Importacion de Librerias

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# Una vez importadas las librerias necesarias para trabajar se importa la base de datos a utilizar que en nuestro caso es un txt relacionado con datos referentes a peliculas

# %%
df_tab = pd.read_csv("/home/brayan-gzz/Descargas/unclean_data1.csv", encoding='utf8')

# %% [markdown]
# Mostramos el numero de ROWS que traes nuestra pequeña base de datos

# %%
df_tab.shape
# Out:
# (14, 16)

# %% [markdown]
# Nos damos una idea de la informacion que contiene el archivo importado en resumen

# %%
df_tab.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# Mostramos la base de datos con su contenido  de manera general

# %%
df_tab
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# Nos debetia de regresar el los tipos de datos pero retona que el dtype es Object junto con los de cada columna

# %%
df_tab.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %% [markdown]
# Nos regresa las columnas contenidas en la pequeña base de datos contenida en el archivo

# %%
df_tab.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
Mostramos todas los datos para obtener un amplio panorama de los datos
# Out:
#   File "<ipython-input-22-d99e3d1e2d76>", line 1
#     Mostramos todas los datos para obtener un amplio panorama de los datos
#                   ^
# SyntaxError: invalid syntax

# %%
df_tab
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# ### La ultima columna no me servia por lo tanto la eliminamos

# %%
df_tab.drop('title_year.1',axis = 1 )
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# Mayor numero de votos dentro de estas peliculas

# %%
df_tab['num_voted_users'].max()
# Out:
# 1144337.0

# %% [markdown]
# y el minimo de votos que existe en es set de datos

# %%
df_tab['num_voted_users'].min()
# Out:
# 212204.0

# %%
df_tab.title_year.unique()
# Out:
# array([2009, 2007, 2015, 2012, 2010, 2016, 2006, 2008])

# %% [markdown]
# Se obtuvieron las fechas unicas

# %%
clase_1 = df_tab[df_tab['title_year']==2015]

# %% [markdown]
# Se hace una agrupacion por año en este caso es 2015 y lo guardamos como clase_1

# %%
clase_1
# Out:
#                  movie_title  num_critic_for_reviews  duration  \
# 2                  Spectre?ÿ                     602     148.0
# 7  Avengers: Age of Ultron?ÿ                     635     141.0
# 8  Avengers: Age of Ultron?ÿ                     635     141.0
#
#   DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 2                      20                     161                   11000
# 7                      10                   19000                   26000
# 8                      10                   19000                   26000
#
#        gross  num_voted_users  Cast_Total_facebook_likes  \
# 2  200074175         275868.0                    11700.0
# 7  458991599         462669.0                    92000.0
# 8  458991599         462669.0                    92000.0
#
#    facenumber_in_poster  num_user_for_reviews     budget  title_year  \
# 2                   1.0                   994  245000000        2015
# ...

# %% [markdown]
# Se agruparon los datos a correspondientes a la clase_1

# %%
clase_1.to_csv('movies_2015.csv', index=False)

# %% [markdown]
# La importancia de las agrupaciones es para poder obtener sub conjuntos o muestras de una poblacion para hacer purbas mas certeras con datos mas especificos, como por ejemplo cuando se quiere estudiar solamente determinada zona o lugar, o cuando solo se requieren estudiar datos que cumplan cierta condicion(promedio, algun valor en especifico(numero, porcentaje, boleano)).

# %%
clase_1.rename(columns = {'movie_title':'pelicula', 'duration': 'duracion', 'num_critic_for_reviews':'numero_critico_reviciones', 'title_year':'año'})
# Out:
#                     pelicula  numero_critico_reviciones  duracion  \
# 2                  Spectre?ÿ                        602     148.0
# 7  Avengers: Age of Ultron?ÿ                        635     141.0
# 8  Avengers: Age of Ultron?ÿ                        635     141.0
#
#   DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 2                      20                     161                   11000
# 7                      10                   19000                   26000
# 8                      10                   19000                   26000
#
#        gross  num_voted_users  Cast_Total_facebook_likes  \
# 2  200074175         275868.0                    11700.0
# 7  458991599         462669.0                    92000.0
# 8  458991599         462669.0                    92000.0
#
#    facenumber_in_poster  num_user_for_reviews     budget   año  \
# 2                   1.0                   994  245000000  2015
# ...

# %% [markdown]
# Modificaciones de tres columnas de una agrupacion

# %%
clase_1.drop('title_year.1',axis = 1 )
# Out:
#                  movie_title  num_critic_for_reviews  duration  \
# 2                  Spectre?ÿ                     602     148.0
# 7  Avengers: Age of Ultron?ÿ                     635     141.0
# 8  Avengers: Age of Ultron?ÿ                     635     141.0
#
#   DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 2                      20                     161                   11000
# 7                      10                   19000                   26000
# 8                      10                   19000                   26000
#
#        gross  num_voted_users  Cast_Total_facebook_likes  \
# 2  200074175         275868.0                    11700.0
# 7  458991599         462669.0                    92000.0
# 8  458991599         462669.0                    92000.0
#
#    facenumber_in_poster  num_user_for_reviews     budget  title_year  \
# 2                   1.0                   994  245000000        2015
# ...

# %% [markdown]
# El analisis previo es necesario para determinar que nos combiene quitar, que datos nos podrian definir las agrupaciones, y que columnas podrian responder preguntas insteresantes, si se elimina o modifican datos sin saber que es lo que realmente representan podriamos perder respuestas valiosas

# %%
df_tab.isnull().any()
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %%
df_0 = df_tab.fillna(0)

# %%
df_0
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# DataFrame sin celdas NaN o vacias

# %% [markdown]
#  método DataFrame.astype() se utiliza para convertir un objeto pandas en un dtype especificado. astype() función astype() también proporciona la capacidad de convertir cualquier columna existente adecuada a tipo categórico.

# %%
df_tab = df_tab.astype({ "movie_title" : 'category'})

# %%
df_tab['movie_title'].dtype
# Out:
# CategoricalDtype(categories=['Avatar?ÿ', 'Avengers: Age of Ultron?ÿ',
#                   'Batman v Superman: Dawn of Justice?ÿ',
#                   'Harry Potter and the Half-Blood Prince?ÿ', 'John Carter?ÿ',
#                   'Pirates of the Caribbean: At World's End?ÿ',
#                   'Pirates of the Caribbean: Dead Man's Chest?ÿ',
#                   'Quantum of Solace?ÿ', 'Spectre?ÿ', 'Spider-Man 3?ÿ',
#                   'Superman Returns?ÿ', 'Tangled?ÿ',
#                   'The Dark Knight Rises?ÿ'],
#                  ordered=False)
